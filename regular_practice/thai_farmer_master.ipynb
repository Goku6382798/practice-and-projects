# %%
import pandas as pd
import datetime

# %%
thai_farmer_master = pd.read_csv('/home/ananta/personnel_study_material/practice-and-projects/regular_practice/Thai_farmer_master.csv')

# %%
thai_farmer_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20688 entries, 0 to 20687
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FARMER NAME       13735 non-null  object
#  1   FARMER LAST NAME  13251 non-null  object
#  2   ZoneId            13735 non-null  float64
#  3   TERRITORYId       5709 non-null   float64
#  4   BUID              3796 non-null   float64
#  5   DeptID            3796 non-null   float64
#  6   ProvienceId       13225 non-null  float64
#  7   DistrictId        12336 non-null  float64
#  8   SubdistrictId     9503 non-null   float64
#  9   FarmercategoryID  13735 non-null  float64
#  10  VILLAGE NAME      11567 non-null  object
#  11  HOME NO.          12483 non-null  object
#  12  TELEPHONE NO.     6414 non-null   object
#  13  MDO               12078 non-null  object
#  14  DSM               13257 non-null  object
#  15  LINE CONTACT      112 non-null    object
# ...

# %%
thai_farmer_master.columns
# Out:
# Index(['FARMER NAME', 'FARMER LAST NAME', 'ZoneId', 'TERRITORYId', 'BUID',
#        'DeptID', 'ProvienceId', 'DistrictId', 'SubdistrictId',
#        'FarmercategoryID', 'VILLAGE NAME', 'HOME NO.', 'TELEPHONE NO.', 'MDO',
#        'DSM', 'LINE CONTACT', 'FACE BOOK', 'MDO_ID', 'DSM_ID', 'isActive',
#        'createdon', 'modifiedon', 'createdby', 'modifiedby', 'CountryID'],
#       dtype='object')

# %%
thai_farmer_master = thai_farmer_master[['FARMER NAME', 'FARMER LAST NAME','VILLAGE NAME', 'HOME NO.', 'TELEPHONE NO.', 'MDO',
       'DSM', 'LINE CONTACT', 'FACE BOOK', 'isActive',
       'CountryID']]
thai_farmer_master.columns
# Out:
# Index(['FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME', 'HOME NO.',
#        'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK', 'isActive',
#        'CountryID'],
#       dtype='object')

# %%
thai_farmer_master
# Out:
#            FARMER NAME FARMER LAST NAME  VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0             ดวงมาลย์           ไชยแสง           NaN      NaN           NaN
# 1               จิราพร       น้อยพันธุ์           NaN      NaN           NaN
# 2           วิไลลักษณ์         ฉายฉันท์           NaN      NaN           NaN
# 3            เจริญพงษ์        การีหว่าง           NaN      NaN           NaN
# 4                ธงไชย        การีหว่าง           NaN      NaN           NaN
# ...                ...              ...           ...      ...           ...
# 20683       นายสายัณห์            สวนสี      แม่สลิด1      NaN   614094433.0
# 20684  นางสาวธิดารัตน์         จันทร์โท      แม่สลิด1      NaN   859033655.0
# 20685            คำปัน   เมืองจันทร์หอม  พระธาตุผาแดง      NaN   826181952.0
# 20686            รัฐพล      ภูมิพระธาตุ       ขเนจื้อ      NaN   930362254.0
# 20687          ผ่องศรี             คำปา      แม่สลิด1      NaN   823497974.0
#
# ...

# %%
thai_farmer_master.columns
# Out:
# Index(['FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME', 'HOME NO.',
#        'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK', 'isActive',
#        'CountryID'],
#       dtype='object')

# %%
thai_farmer_master['createdby'] = 'Admin'
thai_farmer_master.columns
# Out:
# Index(['FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME', 'HOME NO.',
#        'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK', 'isActive',
#        'CountryID', 'createdby'],
#       dtype='object')

# %%
thai_farmer_master.head()
# Out:
#   FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4       ธงไชย        การีหว่าง          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
#
#    CountryID createdby
# 0          7     Admin
# 1          7     Admin
# 2          7     Admin
# 3          7     Admin
# ...

# %%
thai_farmer_master['created_on'] = datetime.datetime.now()
thai_farmer_master.head()
# Out:
#   FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4       ธงไชย        การีหว่าง          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
#
#    CountryID createdby                 created_on
# 0          7     Admin 2025-10-14 11:10:30.170963
# ...

# %%
thai_farmer_master['modified_on'] = datetime.datetime.now()
thai_farmer_master.head()
# Out:
#   FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4       ธงไชย        การีหว่าง          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
#
#    CountryID createdby                 created_on                modified_on
# ...

# %%
thai_farmer_master['modified_by'] = 'null'
thai_farmer_master.head()
# Out:
#   FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4       ธงไชย        การีหว่าง          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
#
#    CountryID createdby                 created_on                modified_on  \
# ...

# %%
thai_farmer_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20688 entries, 0 to 20687
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FARMER NAME       13735 non-null  object
#  1   FARMER LAST NAME  13251 non-null  object
#  2   VILLAGE NAME      11567 non-null  object
#  3   HOME NO.          12483 non-null  object
#  4   TELEPHONE NO.     6414 non-null   object
#  5   MDO               12078 non-null  object
#  6   DSM               13257 non-null  object
#  7   LINE CONTACT      112 non-null    object
#  8   FACE BOOK         47 non-null     object
#  9   isActive          20688 non-null  int64
#  10  CountryID         20688 non-null  int64
#  11  createdby         20688 non-null  object
#  12  created_on        20688 non-null  datetime64[us]
#  13  modified_on       20688 non-null  datetime64[us]
#  14  modified_by       20688 non-null  object
# dtypes: datetime64[us](2), int64(2), object(11)
# ...

# %%
thai_farmer_master['FARMER_ID'] = range(1, len(thai_farmer_master) + 1)
thai_farmer_master.head()
# Out:
#   FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4       ธงไชย        การีหว่าง          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
#
#    CountryID createdby                 created_on                modified_on  \
# ...

# %%
cols = thai_farmer_master.columns.tolist()
cols.insert(0, cols.pop())
thai_farmer_master = thai_farmer_master[cols]
print(thai_farmer_master.columns)
# Out:
# Index(['FARMER_ID', 'FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME',
#        'HOME NO.', 'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK',
#        'isActive', 'CountryID', 'createdby', 'created_on', 'modified_on',
#        'modified_by'],
#       dtype='object')

# %%
thai_farmer_master.columns
# Out:
# Index(['FARMER_ID', 'FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME',
#        'HOME NO.', 'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK',
#        'isActive', 'CountryID', 'createdby', 'created_on', 'modified_on',
#        'modified_by'],
#       dtype='object')

# %%
filtered = thai_farmer_master[
    (thai_farmer_master['FARMER NAME'] == 'SANAN') &
    (thai_farmer_master['FARMER LAST NAME'] == 'DUANGKAEW')
]

# %%
thai_farmer_master
# Out:
#        FARMER_ID      FARMER NAME FARMER LAST NAME  VILLAGE NAME HOME NO.  \
# 0              1         ดวงมาลย์           ไชยแสง           NaN      NaN
# 1              2           จิราพร       น้อยพันธุ์           NaN      NaN
# 2              3       วิไลลักษณ์         ฉายฉันท์           NaN      NaN
# 3              4        เจริญพงษ์        การีหว่าง           NaN      NaN
# 4              5            ธงไชย        การีหว่าง           NaN      NaN
# ...          ...              ...              ...           ...      ...
# 20683      20684       นายสายัณห์            สวนสี      แม่สลิด1      NaN
# 20684      20685  นางสาวธิดารัตน์         จันทร์โท      แม่สลิด1      NaN
# 20685      20686            คำปัน   เมืองจันทร์หอม  พระธาตุผาแดง      NaN
# 20686      20687            รัฐพล      ภูมิพระธาตุ       ขเนจื้อ      NaN
# 20687      20688          ผ่องศรี             คำปา      แม่สลิด1      NaN
#
#       TELEPHONE NO.                         MDO           DSM LINE CONTACT  \
# ...

# %%
intermidate_employee = pd.read_csv('/home/ananta/personnel_study_material/practice-and-projects/regular_practice/intermediate_employee_master_Thai.csv')

# %%
intermidate_employee.columns
# Out:
# Index(['EMP_ID', 'EMP_Name', 'Telephone Number', 'Business Unit', 'roleName',
#        'Email Address', 'BUID'],
#       dtype='object')

# %%
thai_farmer_master.columns
# Out:
# Index(['FARMER_ID', 'FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME',
#        'HOME NO.', 'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK',
#        'isActive', 'CountryID', 'createdby', 'created_on', 'modified_on',
#        'modified_by'],
#       dtype='object')

# %%
intermidate_employee
# Out:
#     EMP_ID             EMP_Name  Telephone Number Business Unit roleName  \
# 0        1               VACANT               NaN            CP      MDO
# 1        2      NATTARAT MATURA       837615100.0            CP      MDO
# 2        3  SITTHICHAI PHONGSRI       917435971.0            CP      MDO
# 3        4    NAPHATSORN POMLOI       902439218.0            CP      MDO
# 4        5      ANUPHONG JUNJUY       863089244.0            CP      MDO
# ..     ...                  ...               ...           ...      ...
# 61      62  PHONGPHAT SRITATERA       839661197.0           NaN      NCO
# 62      63     TAWEE SAENGWIJIT       862460272.0           NaN      NCO
# 63      64  THANAKORN THONGTHAI       981505590.0           NaN      NCO
# 64      65    RANGSAN NONG-NGOK       837489418.0           NaN      NCO
# 65      66    APIWAT SUKSUPHAET       871253373.0           NaN      NCO
#
#    Email Address  BUID
# 0            NaN   1.0
# 1            NaN   1.0
# ...

# %%
thai_farmer_master
# Out:
#        FARMER_ID      FARMER NAME FARMER LAST NAME  VILLAGE NAME HOME NO.  \
# 0              1         ดวงมาลย์           ไชยแสง           NaN      NaN
# 1              2           จิราพร       น้อยพันธุ์           NaN      NaN
# 2              3       วิไลลักษณ์         ฉายฉันท์           NaN      NaN
# 3              4        เจริญพงษ์        การีหว่าง           NaN      NaN
# 4              5            ธงไชย        การีหว่าง           NaN      NaN
# ...          ...              ...              ...           ...      ...
# 20683      20684       นายสายัณห์            สวนสี      แม่สลิด1      NaN
# 20684      20685  นางสาวธิดารัตน์         จันทร์โท      แม่สลิด1      NaN
# 20685      20686            คำปัน   เมืองจันทร์หอม  พระธาตุผาแดง      NaN
# 20686      20687            รัฐพล      ภูมิพระธาตุ       ขเนจื้อ      NaN
# 20687      20688          ผ่องศรี             คำปา      แม่สลิด1      NaN
#
#       TELEPHONE NO.                         MDO           DSM LINE CONTACT  \
# ...

# %%
thai_farmer_master['MDO'] = thai_farmer_master['MDO'].str.strip().str.upper()
intermidate_employee['EMP_Name'] = intermidate_employee['EMP_Name'].str.strip().str.upper()
#x = pd.merge(thai_farmer_master,intermidate_employee,left_on='MDO',right_on='EMP_Name',how='left')

# %%
intermidate_employee.columns
# Out:
# Index(['EMP_ID', 'EMP_Name', 'Telephone Number', 'Business Unit', 'roleName',
#        'Email Address', 'BUID'],
#       dtype='object')

# %%
x = intermidate_employee[['EMP_ID','EMP_Name']].copy()

# %%
x
# Out:
#     EMP_ID             EMP_Name
# 0        1               VACANT
# 1        2      NATTARAT MATURA
# 2        3  SITTHICHAI PHONGSRI
# 3        4    NAPHATSORN POMLOI
# 4        5      ANUPHONG JUNJUY
# ..     ...                  ...
# 61      62  PHONGPHAT SRITATERA
# 62      63     TAWEE SAENGWIJIT
# 63      64  THANAKORN THONGTHAI
# 64      65    RANGSAN NONG-NGOK
# 65      66    APIWAT SUKSUPHAET
#
# [66 rows x 2 columns]

# %%
print(thai_farmer_master.columns)
x.columns
# Out:
# Index(['FARMER_ID', 'FARMER NAME', 'FARMER LAST NAME', 'VILLAGE NAME',
#        'HOME NO.', 'TELEPHONE NO.', 'MDO', 'DSM', 'LINE CONTACT', 'FACE BOOK',
#        'isActive', 'CountryID', 'createdby', 'created_on', 'modified_on',
#        'modified_by'],
#       dtype='object')
# Index(['EMP_ID', 'EMP_Name'], dtype='object')

# %%
x['EMP_Name']
# Out:
# 0                  VACANT
# 1         NATTARAT MATURA
# 2     SITTHICHAI PHONGSRI
# 3       NAPHATSORN POMLOI
# 4         ANUPHONG JUNJUY
#              ...
# 61    PHONGPHAT SRITATERA
# 62       TAWEE SAENGWIJIT
# 63    THANAKORN THONGTHAI
# 64      RANGSAN NONG-NGOK
# 65      APIWAT SUKSUPHAET
# Name: EMP_Name, Length: 66, dtype: object

# %%
print(thai_farmer_master.shape)
x.shape
# Out:
# (20688, 16)
# (66, 2)

# %%
x = x.rename(columns={"EMP_Name":"MDO"})

# %%
new  = pd.merge(thai_farmer_master,x, on = ['MDO'], how ='left')
new
# Out:
#        FARMER_ID      FARMER NAME FARMER LAST NAME  VILLAGE NAME HOME NO.  \
# 0              1         ดวงมาลย์           ไชยแสง           NaN      NaN
# 1              2           จิราพร       น้อยพันธุ์           NaN      NaN
# 2              3       วิไลลักษณ์         ฉายฉันท์           NaN      NaN
# 3              4        เจริญพงษ์        การีหว่าง           NaN      NaN
# 4              5            ธงไชย        การีหว่าง           NaN      NaN
# ...          ...              ...              ...           ...      ...
# 20683      20684       นายสายัณห์            สวนสี      แม่สลิด1      NaN
# 20684      20685  นางสาวธิดารัตน์         จันทร์โท      แม่สลิด1      NaN
# 20685      20686            คำปัน   เมืองจันทร์หอม  พระธาตุผาแดง      NaN
# 20686      20687            รัฐพล      ภูมิพระธาตุ       ขเนจื้อ      NaN
# 20687      20688          ผ่องศรี             คำปา      แม่สลิด1      NaN
#
#       TELEPHONE NO.                         MDO           DSM LINE CONTACT  \
# ...

# %%
new.head(6)
# Out:
#    FARMER_ID FARMER NAME FARMER LAST NAME VILLAGE NAME HOME NO. TELEPHONE NO.  \
# 0          1    ดวงมาลย์           ไชยแสง          NaN      NaN           NaN
# 1          2      จิราพร       น้อยพันธุ์          NaN      NaN           NaN
# 2          3  วิไลลักษณ์         ฉายฉันท์          NaN      NaN           NaN
# 3          4   เจริญพงษ์        การีหว่าง          NaN      NaN           NaN
# 4          5       ธงไชย        การีหว่าง          NaN      NaN           NaN
# 5          6       สำรวย          สาวรีย์          NaN      NaN           NaN
#
#                    MDO           DSM LINE CONTACT FACE BOOK  isActive  \
# 0  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 1  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 2  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 3  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# 4  ANUCHA   POSRITHONG  MR.PORNSAWAN          NaN       NaN         1
# ...

# %%
new[new['EMP_ID'].isna()]
# Out:
#        FARMER_ID FARMER NAME FARMER LAST NAME      VILLAGE NAME HOME NO.  \
# 0              1    ดวงมาลย์           ไชยแสง               NaN      NaN
# 1              2      จิราพร       น้อยพันธุ์               NaN      NaN
# 2              3  วิไลลักษณ์         ฉายฉันท์               NaN      NaN
# 3              4   เจริญพงษ์        การีหว่าง               NaN      NaN
# 4              5       ธงไชย        การีหว่าง               NaN      NaN
# ...          ...         ...              ...               ...      ...
# 20501      20502      วีรชัย           กองมณี    บ้านหินซ้อนใต้    116/2
# 20502      20503      สุภาพร           กอมมณี    บ้านหินซ้อนใต้    116/2
# 20503      20504       พิษณุ          แสงอรุณ        บ้านซับครก     80/1
# 20504      20505       อำนวย            สุขสี               NaN     83/3
# 20505      20506       ณรงค์        กลิ่นต่าย  บ้านบ้านบ่อมะแฟน     31/2
#
#       TELEPHONE NO.                  MDO           DSM LINE CONTACT FACE BOOK  \
# ...

# %%
y = x.rename(columns={'Emp_id': 'MDO_ID'}) 
y = x.drop(columns=['EMP_Name']) 
y
# Out:
#     EMP_ID
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 61      62
# 62      63
# 63      64
# 64      65
# 65      66
#
# [66 rows x 1 columns]

# %%
th_far_mas = pd.read_csv("Thai_farmer_master.csv")
th_far_mas.columns
# Out:
# Index(['FARMER NAME', 'FARMER LAST NAME', 'ZoneId', 'TERRITORYId', 'BUID',
#        'DeptID', 'ProvienceId', 'DistrictId', 'SubdistrictId',
#        'FarmercategoryID', 'VILLAGE NAME', 'HOME NO.', 'TELEPHONE NO.', 'MDO',
#        'DSM', 'LINE CONTACT', 'FACE BOOK', 'MDO_ID', 'DSM_ID', 'isActive',
#        'createdon', 'modifiedon', 'createdby', 'modifiedby', 'CountryID'],
#       dtype='object')

# %%
emp_mas = pd.read_csv("Thai_EMPloyee_master.csv")[['EMP_ID','EMP_Name']]
emp_mas.columns
# Out:
# Index(['EMP_ID', 'EMP_Name'], dtype='object')

# %%
emp_mas = emp_mas.rename(columns={"EMP_Name":"MDO"})

emp_mas
# Out:
#     EMP_ID                  MDO
# 0        1               VACANT
# 1        2      NATTARAT MATURA
# 2        3  SITTHICHAI PHONGSRI
# 3        4    NAPHATSORN POMLOI
# 4        5      ANUPHONG JUNJUY
# ..     ...                  ...
# 61      62  PHONGPHAT SRITATERA
# 62      63     TAWEE SAENGWIJIT
# 63      64  THANAKORN THONGTHAI
# 64      65    RANGSAN NONG-NGOK
# 65      66    APIWAT SUKSUPHAET
#
# [66 rows x 2 columns]

# %%
farmer_new = pd.merge(th_far_mas,emp_mas, on = ['MDO'], how = 'left')
farmer_new.isna().sum()
# Out:
# FARMER NAME          6953
# FARMER LAST NAME     7437
# ZoneId               6953
# TERRITORYId         14979
# BUID                16892
# DeptID              16892
# ProvienceId          7463
# DistrictId           8352
# SubdistrictId       11185
# FarmercategoryID     6953
# VILLAGE NAME         9121
# HOME NO.             8205
# TELEPHONE NO.       14274
# MDO                  8610
# DSM                  7431
# LINE CONTACT        20576
# FACE BOOK           20641
# MDO_ID              16892
# DSM_ID              13357
# isActive                0
# createdon           20688
# modifiedon          20688
# createdby               0
# modifiedby          20688
# CountryID               0
# EMP_ID              16892
# dtype: int64

# %%
farmer_new
# Out:
#            FARMER NAME FARMER LAST NAME  ZoneId  TERRITORYId  BUID  DeptID  \
# 0             ดวงมาลย์           ไชยแสง     1.0          NaN   NaN     NaN
# 1               จิราพร       น้อยพันธุ์     1.0          NaN   NaN     NaN
# 2           วิไลลักษณ์         ฉายฉันท์     1.0          NaN   NaN     NaN
# 3            เจริญพงษ์        การีหว่าง     1.0          NaN   NaN     NaN
# 4                ธงไชย        การีหว่าง     1.0          NaN   NaN     NaN
# ...                ...              ...     ...          ...   ...     ...
# 20683       นายสายัณห์            สวนสี     6.0         13.0   2.0     1.0
# 20684  นางสาวธิดารัตน์         จันทร์โท     6.0         13.0   2.0     1.0
# 20685            คำปัน   เมืองจันทร์หอม     6.0         13.0   2.0     1.0
# 20686            รัฐพล      ภูมิพระธาตุ     6.0         13.0   2.0     1.0
# 20687          ผ่องศรี             คำปา     6.0         13.0   2.0     1.0
#
# ...

# %%
temp = farmer_new[['MDO','MDO_ID']]

# %%
temp[temp['MDO_ID']==20]
# Out:
#                  MDO  MDO_ID
# 20256  WARIT SURAKUN    20.0
# 20257  WARIT SURAKUN    20.0
# 20258  WARIT SURAKUN    20.0
# 20259  WARIT SURAKUN    20.0
# 20260  WARIT SURAKUN    20.0
# 20261  WARIT SURAKUN    20.0
# 20262  WARIT SURAKUN    20.0
# 20263  WARIT SURAKUN    20.0
# 20264  WARIT SURAKUN    20.0
# 20265  WARIT SURAKUN    20.0
# 20266  WARIT SURAKUN    20.0
# 20267  WARIT SURAKUN    20.0
# 20268  WARIT SURAKUN    20.0
# 20269  WARIT SURAKUN    20.0
# 20270  WARIT SURAKUN    20.0

# %%
farmer_new['MDO_ID'].unique()
# Out:
# array([nan, 21., 28., 22., 19., 27., 20., 63., 38., 40., 37., 34., 33.,
#        35., 43., 42.])
